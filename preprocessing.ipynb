# %%
# %pip install xlrd openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

file_path = 'institusi-korporasi-finansial-----neraca-institusi-terintegrasi--triliun-rupiah-.xls'

df = pd.read_excel(file_path)
df.head()
# Out:
#   Korporasi Finansial - Neraca Institusi Terintegrasi (Triliun Rupiah), 2016-2024  \
# 0                                                NaN
# 1                                               Kode
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#         Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4   Unnamed: 5 Unnamed: 6  \
# 0              NaN        NaN         NaN        NaN          NaN        NaN
# 1      Klasifikasi        NaN        2016        NaN          NaN        NaN
# 2              NaN        NaN  Triwulan I        NaN  Triwulan II        NaN
# 3              NaN        NaN  Penggunaan     Sumber   Penggunaan     Sumber
# 4  Neraca produksi        NaN         NaN        NaN          NaN        NaN
#
#      Unnamed: 7 Unnamed: 8   Unnamed: 9  ... Unnamed: 83 Unnamed: 84  \
# 0           NaN        NaN          NaN  ...         NaN         NaN
# ...
